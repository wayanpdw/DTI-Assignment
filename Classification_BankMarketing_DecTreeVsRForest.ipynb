# %% [markdown]
# <a href="https://colab.research.google.com/github/wayanpdw/DTI-Assignment/blob/master/Classification_BankMarketing_DecTreeVsRForest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Algoritma Klasifikasi**
# I Wayan Pasek Dian Wahyudi | DS0114 | Telkom DTI 2020
#
# Terdapat 4 metode algoritma klasifikasi, diantaranya:
#
# *   Decicion Tree (struktur pohon/ hierarki)
# *   Random Forest (penggabungan decicion tree)
# *   Naive Bayes (prediksi berdasarkan masa lalu)
# *   Lazy Learner (K Nearest Neighbor)
#
# Pada *assignment* kali ini akan diuji dan dibandingkan 2 performa dari algoritma klasifikasi yaitu ***Decicion Tree*** dan ***Random Forest***.
#
# Pemodelan algoritma klasifikasi pada proyek ini akan menggunakan dataset marketing perbankan yang tersedia di https://www.kaggle.com/janiobachmann/bank-marketing-dataset . Dengan atribut :
#
#
# age: (numeric)
#
# job: type of job (categorical: 'admin.','blue-collar','entrepreneur','housemaid','management','retired','self-employed','services','student','technician','unemployed','unknown')
#
# marital: marital status (categorical: 'divorced','married','single','unknown'; note: 'divorced' means divorced or widowed)
#
# education: (categorical: primary, secondary, tertiary and unknown)
#
# default: has credit in default? (categorical: 'no','yes','unknown')
#
# housing: has housing loan? (categorical: 'no','yes','unknown')
#
# loan: has personal loan? (categorical: 'no','yes','unknown')
#
# balance: Balance of the individual.
#
# contact: contact communication type (categorical: 'cellular','telephone')
#
# month: last contact month of year (categorical: 'jan', 'feb', 'mar', ..., 'nov', 'dec')
#
# day: last contact day of the month (numeric: 1,2,3,....29,30)
#
# duration: last contact duration, in seconds (numeric). Important note: this attribute highly affects the output target (e.g., if duration=0 then y='no'). Yet, the duration is not known before a call is performed. Also, after the end of the call y is obviously known. Thus, this input should only be included for benchmark purposes and should be discarded if the intention is to have a realistic predictive model.
#
# campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
#
# pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric; 999 means client was not previously contacted)
#
# previous: number of contacts performed before this campaign and for this client (numeric)
#
# poutcome: outcome of the previous marketing campaign (categorical: 'failure','nonexistent','success')
#
# deposit - has the client subscribed a term deposit? (binary: 'yes','no')

# %% [markdown]
# # **Menyiapkan data**
# **Import library**

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.externals.six import StringIO
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus
import os
from sklearn import metrics
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Mengimport data mentah dari bank dengan library pandas dan memunculkan 5 data pertama dalam dataframe baru.**

# %%
df_databank = pd.read_csv('https://raw.githubusercontent.com/elienhanj/classification_bankmarketing/main/bank.csv', sep = ',')
df_databank

df_databank.head()
# Out:
#    age         job  marital  education  ... pdays  previous poutcome deposit
# 0   59      admin.  married  secondary  ...    -1         0  unknown     yes
# 1   56      admin.  married  secondary  ...    -1         0  unknown     yes
# 2   41  technician  married  secondary  ...    -1         0  unknown     yes
# 3   55    services  married  secondary  ...    -1         0  unknown     yes
# 4   54      admin.  married   tertiary  ...    -1         0  unknown     yes
#
# [5 rows x 17 columns]

# %% [markdown]
# **Menampilkan informasi dari dataset bank**

# %%
df_databank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11162 entries, 0 to 11161
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        11162 non-null  int64
#  1   job        11162 non-null  object
#  2   marital    11162 non-null  object
#  3   education  11162 non-null  object
#  4   default    11162 non-null  object
#  5   balance    11162 non-null  int64
#  6   housing    11162 non-null  object
#  7   loan       11162 non-null  object
#  8   contact    11162 non-null  object
#  9   day        11162 non-null  int64
#  10  month      11162 non-null  object
#  11  duration   11162 non-null  int64
#  12  campaign   11162 non-null  int64
#  13  pdays      11162 non-null  int64
#  14  previous   11162 non-null  int64
#  15  poutcome   11162 non-null  object
#  16  deposit    11162 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 1.4+ MB

# %% [markdown]
# **Dari informasi data diatas, terdapat dua jenis tipe data yaitu integer dan object. Data integer kita ambil untuk membuat Descriptive Statistics.**
#
# **Berikut tampilan Descriptive Statistics-nya.**

# %%
df_databank.describe().transpose()
# Out:
#             count         mean          std  ...    50%      75%      max
# age       11162.0    41.231948    11.913369  ...   39.0    49.00     95.0
# balance   11162.0  1528.538524  3225.413326  ...  550.0  1708.00  81204.0
# day       11162.0    15.658036     8.420740  ...   15.0    22.00     31.0
# duration  11162.0   371.993818   347.128386  ...  255.0   496.00   3881.0
# campaign  11162.0     2.508421     2.722077  ...    2.0     3.00     63.0
# pdays     11162.0    51.330407   108.758282  ...   -1.0    20.75    854.0
# previous  11162.0     0.832557     2.292007  ...    0.0     1.00     58.0
#
# [7 rows x 8 columns]

# %% [markdown]
# #**Data Preprocessing**
# **Setelah selesai menyiapkan data, kita masuk ke tahap Data Preprocessing. Dimana data yg sudah disiapkan diolah kembali untuk keperluan pemodelan data.**
#
# **Pertama kita akan mengecek Missing value/ data hilang.**

# %%
df_databank.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# deposit      0
# dtype: int64

# %% [markdown]
# **Tidak ada missing value data/ bernilai NULL.**
#
# **Encode Categorical Data**

# %%
# Encoder
encoder = OneHotEncoder(sparse=False) 

# Encode Categorical Data
features = ["job", "marital", "education", "default", "housing", "loan", "contact", "month", "poutcome"]
df_encoded = pd.DataFrame(encoder.fit_transform(df_databank[features]))
df_encoded.columns = encoder.get_feature_names(features)

# Mengganti Categorical Data dengan Encoded Data
df_databank.drop(features, axis=1, inplace=True)
df_encoded = pd.concat([df_databank, df_encoded], axis=1)

# Menampilkan Encoded DataFrame
df_encoded
# Out:
#        age  balance  day  ...  poutcome_other  poutcome_success  poutcome_unknown
# 0       59     2343    5  ...             0.0               0.0               1.0
# 1       56       45    5  ...             0.0               0.0               1.0
# 2       41     1270    5  ...             0.0               0.0               1.0
# 3       55     2476    5  ...             0.0               0.0               1.0
# 4       54      184    5  ...             0.0               0.0               1.0
# ...    ...      ...  ...  ...             ...               ...               ...
# 11157   33        1   20  ...             0.0               0.0               1.0
# 11158   39      733   16  ...             0.0               0.0               1.0
# 11159   32       29   19  ...             0.0               0.0               1.0
# 11160   43        0    8  ...             0.0               0.0               0.0
# 11161   34        0    9  ...             0.0               0.0               1.0
#
# [11162 rows x 52 columns]

# %% [markdown]
# **Menentukan Feature dan Target**

# %%
# Menentukan Feature
feature = df_encoded.drop(['deposit'], axis=1)
feature
# Out:
#        age  balance  day  ...  poutcome_other  poutcome_success  poutcome_unknown
# 0       59     2343    5  ...             0.0               0.0               1.0
# 1       56       45    5  ...             0.0               0.0               1.0
# 2       41     1270    5  ...             0.0               0.0               1.0
# 3       55     2476    5  ...             0.0               0.0               1.0
# 4       54      184    5  ...             0.0               0.0               1.0
# ...    ...      ...  ...  ...             ...               ...               ...
# 11157   33        1   20  ...             0.0               0.0               1.0
# 11158   39      733   16  ...             0.0               0.0               1.0
# 11159   32       29   19  ...             0.0               0.0               1.0
# 11160   43        0    8  ...             0.0               0.0               0.0
# 11161   34        0    9  ...             0.0               0.0               1.0
#
# [11162 rows x 51 columns]

# %%
# Menentukan Target
target = df_encoded['deposit']
target
# Out:
# 0        yes
# 1        yes
# 2        yes
# 3        yes
# 4        yes
#         ...
# 11157     no
# 11158     no
# 11159     no
# 11160     no
# 11161     no
# Name: deposit, Length: 11162, dtype: object

# %% [markdown]
# **Mengeset Data Training dan Data Testing**

# %%
# Mengatur data training dan data testing (80:20)
from sklearn.model_selection import train_test_split, cross_val_score
X_train, X_test, y_train, y_test  = train_test_split(feature , target, shuffle = True, test_size=0.2, random_state=1)

# Menampilkan data training dan testing
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (8929, 51)
# (2233, 51)
# (8929,)
# (2233,)

# %%
X_test.head()
# Out:
#       age  balance  day  ...  poutcome_other  poutcome_success  poutcome_unknown
# 8422   31      554    5  ...             0.0               0.0               1.0
# 9226   43      514   20  ...             0.0               0.0               1.0
# 8162   26      277   14  ...             0.0               0.0               1.0
# 4337   39       91    3  ...             0.0               1.0               0.0
# 2438   40        0    6  ...             0.0               1.0               0.0
#
# [5 rows x 51 columns]

# %% [markdown]
# **Setelah menentukan Testing Data dan Training data maka proses persiapan data sudah selesai dan data siap digunakan untuk pengujian model yang sudah ditentukan.**
#
# # **Decicion Tree Modelling**
#
# **Dibawah ini adalah langkah-langkah pembuatan model Decicion Tree.**

# %%
# Inisialisasi parameter
dtc = tree.DecisionTreeClassifier(min_impurity_decrease=0.01)
dtc.fit(X_train, y_train)

# Predict to Test Data 
y_pred_dtc = dtc.predict(X_test)

# %%
# Menampilkan Tree
dot_data = StringIO()
export_graphviz(dtc, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,
                class_names='deposit',
                feature_names=X_train.columns)

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %% [markdown]
# **Model Evaluation**
#
# **Setelah tahap Modelling Decicion Tree selesai, kita akan membua Model Evaluation-nya.**
#
# **Langkah pertama, kita membuat Confussion Matrix agar kita bisa memvisualkan kinerja dari model yang kita buat.**

# %%
cm = metrics.confusion_matrix(y_test, y_pred_dtc)
cm
# Out:
# array([[815, 350],
#        [157, 911]])

# %% [markdown]
# **menampilkan nilai akurasi, precission, recall, F1 score dan cohens kappa score untuk model random forest.**

# %%
acc_dtc = metrics.accuracy_score(y_test, y_pred_dtc)
prec_dtc = metrics.precision_score(y_test, y_pred_dtc, pos_label='yes')
rec_dtc = metrics.recall_score(y_test, y_pred_dtc, pos_label='yes')
f1_dtc = metrics.f1_score(y_test, y_pred_dtc, pos_label='yes')
coh_kappa_dtc = metrics.cohen_kappa_score(y_test, y_pred_dtc)

print("Accuracy:", acc_dtc)
print("Precision:", prec_dtc)
print("Recall:", rec_dtc)
print("F1 Score:", f1_dtc)
print("Cohens Kappa Score:", coh_kappa_dtc)
# Out:
# Accuracy: 0.7729511867442902
# Precision: 0.7224425059476606
# Recall: 0.852996254681648
# F1 Score: 0.7823100042936882
# Cohens Kappa Score: 0.5484410454693576

# %% [markdown]
# **Membuat Kurva ROC**
#
# **Kurva ROC (Receiver Operating Characteristics) adalah alat ukur performance untuk classification problem dalam menentukan threshold dari suatu model.**

# %%
# Tentukan ukuran dan style-nya
plt.rcParams['figure.figsize'] = (10, 10)
plt.style.use('ggplot')

# Menampilkan Kurva
y_pred_dtc_proba = dtc.predict_proba(X_test)[::,1]
fprdtc, tprdtc, _ = metrics.roc_curve(y_test,  y_pred_dtc_proba, pos_label="yes")
aucdtc = metrics.roc_auc_score(y_test, y_pred_dtc_proba)
plt.plot(fprdtc,tprdtc,label="Decision Tree, auc="+str(aucdtc))
plt.title('Kurva ROC - Decision Tree')
plt.xlabel('false positive rate') 
plt.ylabel('true positive rate')
plt.legend(loc=4)
plt.show()

# %% [markdown]
# **Decicion Tree modelling sudah selesai dilakukan, dengan performance score sebagai berikut :**
#
# *   **Accuracy: 0.7729511867442902**
# *   **Precision: 0.7224425059476606**
# *   **Recall: 0.852996254681648**
# *   **F1 Score: 0.7823100042936882**
# *   **Cohens Kappa Score: 0.5484410454693576**

# %% [markdown]
# # **Random Forest Modelling**
#
# **Dibawah ini adalah tahap-tahap pembuatan model Random Forest**

# %% [markdown]
# **iniialisasi paramter dan membuat data prediksi**

# %%
# inisialisasi parameter
rforest = RandomForestClassifier(n_estimators=50,max_depth=5, 
                                 random_state=101,max_leaf_nodes=50)
rforest.fit(X_train,y_train)

# Predict to Test Data
y_pred_rforest = rforest.predict(X_test)

# %% [markdown]
# **mengeksport data menjadi dot file**

# %%
estimator = rforest.estimators_[5]
export_graphviz(estimator, 
                out_file='rforest.dot', 
                feature_names = X_train.columns,
                class_names = 'deposit',
                rounded = True, proportion = False, 
                precision = 2, filled = True)

# %% [markdown]
# **Merubah file dot menjadi png**

# %%
os.system('dot -Tpng rforest.dot -o rforest.png')
# Out:
# 0

# %% [markdown]
# **Menampilkan visualisasi dari Random Forest**

# %%
from IPython.display import Image
Image(filename = 'rforest.png')

# %% [markdown]
# **Model Evaluation**
#
# **Setelah tahap Modelling Decicion Tree selesai, kita akan membua Model Evaluation-nya.**
#
# **Langkah pertama, kita membuat Confussion Matrix agar kita bisa memvisualkan kinerja dari model yang kita buat.**

# %%
cm = metrics.confusion_matrix(y_test, y_pred_rforest)
cm
# Out:
# array([[969, 196],
#        [221, 847]])

# %% [markdown]
# **menampilkan nilai akurasi, precission, recall, F1 score dan cohens kappa score untuk model random forest.**

# %%
acc_rforest = metrics.accuracy_score(y_test, y_pred_rforest)
prec_rforest = metrics.precision_score(y_test, y_pred_rforest, pos_label='yes')
rec_rforest = metrics.recall_score(y_test, y_pred_rforest, pos_label='yes')
f1_rforest = metrics.f1_score(y_test, y_pred_rforest, pos_label='yes')
coh_kappa_rforest = metrics.cohen_kappa_score(y_test, y_pred_rforest)

print("Accuracy:", acc_rforest)
print("Precision:", prec_rforest)
print("Recall:", rec_rforest)
print("F1 Score:", f1_rforest)
print("Cohens Kappa Score:", coh_kappa_rforest)
# Out:
# Accuracy: 0.8132557098074339
# Precision: 0.8120805369127517
# Recall: 0.7930711610486891
# F1 Score: 0.8024632875414495
# Cohens Kappa Score: 0.625440313111546

# %% [markdown]
# **Membuat Kurva ROC**
#
# **Kurva ROC (Receiver Operating Characteristics) adalah alat ukur performance untuk classification problem dalam menentukan threshold dari suatu model.**

# %%
# Tentukan ukuran dan style-nya
plt.rcParams['figure.figsize'] = (10, 10)
plt.style.use('ggplot')

# Menampilkan Kurva
y_pred_rforest_proba = rforest.predict_proba(X_test)[::,1]
fpr_rforest, tpr_rforest, _ = metrics.roc_curve(y_test,  y_pred_rforest_proba, pos_label="yes")
auc_rforest = metrics.roc_auc_score(y_test, y_pred_rforest_proba)
plt.plot(fpr_rforest,tpr_rforest,label="Random Forest, auc="+str(aucrforest))
plt.title('Kurva ROC - Random Forest')
plt.xlabel('false positive rate') 
plt.ylabel('true positive rate')
plt.legend(loc=4)
plt.show()

# %% [markdown]
# **Random Forest modelling sudah selesai dilakukan, dengan performance score sebagai berikut :**
#
#
# *   **Accuracy: 0.8132557098074339**
# *   **Precision: 0.8120805369127517**
# *   **Recall: 0.7930711610486891**
# *   **F1 Score: 0.8024632875414495**
# *   **Cohens Kappa Score: 0.625440313111546**

# %% [markdown]
# # **Perbandingan Model**
#
# **Perbandingan model dilakukan untuk mengetahui model klasifikasi mana yang mempunyai kinerja lebih baik.**

# %%
# Membandingkan kinerja model

print("Decision Tree Accuracy =",acc_dtc)
print("Decision Tree Precision =",prec_dtc)
print("Decision Tree Recall =",rec_dtc)
print("Decision Tree F1-Score =", f1_dtc)
print("_______________________")
print("Naive Bayes Accuracy =", acc_rforest)
print("Naive Bayes Precision =", prec_rforest)
print("Naive Bayes Recall =", rec_rforest)
print("Naive Bayes F1-Score =", f1_rforest)
# Out:
# Decision Tree Accuracy = 0.7729511867442902
# Decision Tree Precision = 0.7224425059476606
# Decision Tree Recall = 0.852996254681648
# Decision Tree F1-Score = 0.7823100042936882
# _______________________
# Naive Bayes Accuracy = 0.8132557098074339
# Naive Bayes Precision = 0.8120805369127517
# Naive Bayes Recall = 0.7930711610486891
# Naive Bayes F1-Score = 0.8024632875414495

# %% [markdown]
# **Membandingkan Kurva ROC**

# %%
plt.plot(fprdtc,tprdtc,label="Decision Tree, auc="+str(aucdtc))
plt.plot(fpr_rforest,tpr_rforest,label="Random Forest, auc="+str(auc_rforest))
plt.title('Kurva ROC')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc=4)
plt.show()

# %% [markdown]
# **Membuat DaaFrame yang memuat fitur dan prediksi dari masing-masing model**

# %%
# Membuat DataFrame
df_compare = X_test.copy()
df_compare['ActualClass'] = y_test
df_compare['DecisonTree'] = y_pred_dtc
df_compare['NaiveBayes'] = y_pred_rforest

# Menampilkan perbandingan
df_compare.head()
# Out:
#       age  balance  day  ...  ActualClass  DecisonTree  NaiveBayes
# 8422   31      554    5  ...           no           no          no
# 9226   43      514   20  ...           no           no          no
# 8162   26      277   14  ...           no          yes          no
# 4337   39       91    3  ...          yes          yes         yes
# 2438   40        0    6  ...          yes          yes         yes
#
# [5 rows x 54 columns]

# %% [markdown]
# # **Kesimpulan**
#
# **Pada kedua model yang telah dibuat, masing-masing memiliki nilai akurasi, presisi, recall, F1 dan cappa score.**
#
# **Nilai Performa Model Decicion Tree :**
# *   Accuracy: 0.7729511867442902
# *   Precision: 0.7224425059476606
# *   Recall: 0.852996254681648
# *   F1 Score: 0.7823100042936882
# *   Cohens Kappa Score: 0.5484410454693576
#
# **Nilai Performa Model Random Forest :**
# *   Accuracy: 0.7729511867442902
# *   Precision: 0.7224425059476606
# *   Recall: 0.852996254681648
# *   F1 Score: 0.7823100042936882
# *   Cohens Kappa Score: 0.5484410454693576
#
# **Dari Perbandingan kinerja kedua Model diatas dapat disimpulkan bahwa *Random Forest Modelling mempunyai kinerja yang lebih baik* dibandingkan dengan Decicion tree.**
